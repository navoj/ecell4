# %%
from ecell4.util import cyjs

# %%
cyjs.__file__
# Out:
# '/home/domitry/anaconda/lib/python2.7/site-packages/ecell4-0.0.0-py2.7-linux-x86_64.egg/ecell4/util/cyjs.py'

# %%
from ecell4.core import *

# %%
egf = Species("EGF(R)")

# %%
egfr = Species("EGFR(L,CR1,Y1068=P)")

# %%
comp1 = Species("EGFR(L^1,CR1).EGF(R^1)")

# %%
comp2 = Species("EGFR(Y1068=P^1).Grb2(SH2^1)")

# %%
cyjs.init_cyjs()
# Out:
# <script>
# if(window['cytoscape'] === undefined){
#     var paths = {
# 	cytoscape: 'http://cdnjs.cloudflare.com/ajax/libs/cytoscape/2.2.10/cytoscape'
#     };
#
#     console.log('Begin loading all JavaScript libs...');
#     require.config({paths: paths});
#
#     require(['cytoscape'], function(cytoscape){
# 	window['cytoscape'] = cytoscape;
# 	console.log('Finished loading jQuery and Cytoscape.js.');
#
# 	var event = document.createEvent("HTMLEvents");
# 	event.initEvent("load_cytoscape", true, false);
# 	window.dispatchEvent(event);
#     });
# }
# </script>

# %%
cyjs.plot_species(egf)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset=utf-8 />
#     <title>Animated BFS</title>
#     <style type="text/css">
#      body {
#        font: 14px helvetica neue, helvetica, arial, sans-serif;
#      }
#
#      #cybaa57da4-2cfb-480c-bd9a-46753d16569a {
#        height: 500px;
#        width: 500px;
#        position: absolute;
#        left: 0;
#        top: 0;
#      }
#     </style>
#
#     <script>
#      (function(){
#
#        function render(){
# 	 var save_data;
#
# 	 $("#savecybaa57da4-2cfb-480c-bd9a-46753d16569a").click(function(){
# 	   save_data = window.cy.json();
# 	   console.log(save_data);
# 	   console.log(JSON.stringify(save_data));
# 	 });
#
# 	 $("#revertcybaa57da4-2cfb-480c-bd9a-46753d16569a").click(function(){
# 	   $('#cybaa57da4-2cfb-480c-bd9a-46753d16569a').cytoscape(save_data);
# 	 });
#
# 	 $('#cybaa57da4-2cfb-480c-bd9a-46753d16569a').cytoscape({
# 	   style: cytoscape.stylesheet()
# 			   .selector('node')
# 			   .css({
#              'shape': 'data(faveShape)',
#              'background-color': 'data(faveColor)',
#              'content': 'data(name)'
# 	   })
# 			   .selector('edge')
# 			   .css({
#              'target-arrow-shape': 'triangle',
#              'width': 4,
#              'line-color': '#ddd',
#              'target-arrow-color': '#ddd'
# 	   })
# 			   .selector('.highlighted')
# 			   .css({
#              'background-color': '#61bffc',
#              'line-color': '#61bffc',
#              'target-arrow-color': '#61bffc',
#              'transition-property': 'background-color, line-color, target-arrow-color',
#              'transition-duration': '0.5s'
# 	   }),
#
# 	   elements: {
# 	     nodes: [{"data": {"id": "EGF", "name": "EGF"}}, {"data": {"id": "R_EGF", "parent": "EGF", "name": "R"}}],
# 	     edges: []
# 	   },
#
# 	   layout: {
# 	     name: 'breadthfirst',
# 	     directed: true,
# 	     roots: '#a',
# 	     padding: 10
# 	   },
#
# 	   ready: function(){
# 	     window.cy = this;
#
# 	     var bfs = cy.elements().bfs('#a', function(){}, true);
#
# 	     var i = 0;
# 	     var highlightNextEle = function(){
# 	       bfs.path[i].addClass('highlighted');
#
# 	       if( i < bfs.path.length ){
# 		 i++;
# 		 setTimeout(highlightNextEle, 1000);
# 	       }
# 	     };
#
# 	     // kick off first highlight
# 	     highlightNextEle();
# 	   }
# 	 });
#        };
#
#        var before_render = function(){
# 	 if(window['cytoscape'] === undefined){
#            console.log("wait!");
# 	   window.addEventListener("load_cytoscape", before_render);
# 	 }else{
# 	   console.log("begin rendering!");
# 	   render();
# 	 }
#        }
#
#        before_render();
#
#      })();
#     </script>
#   </head>
#   <body>
#     <div id="cybaa57da4-2cfb-480c-bd9a-46753d16569a"></div>
#     <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#     <div id="dammy" style="width:700px;height:500px"></div>
#     <div id="controller"><button id="savecybaa57da4-2cfb-480c-bd9a-46753d16569a">Save position</button><button id="revertcybaa57da4-2cfb-480c-bd9a-46753d16569a">Revert position</button></div>
#   </body>
# </html>

# %%
cyjs.plot_species(egfr)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset=utf-8 />
#     <title>Animated BFS</title>
#     <style type="text/css">
#      body {
#        font: 14px helvetica neue, helvetica, arial, sans-serif;
#      }
#
#      #cyeaff8120-cf16-465f-81c5-b6e50da5c767 {
#        height: 500px;
#        width: 500px;
#        position: absolute;
#        left: 0;
#        top: 0;
#      }
#     </style>
#
#     <script>
#      (function(){
#
#        function render(){
# 	 var save_data;
#
# 	 $("#save").click(function(){
# 	   save_data = window.cy.json();
# 	   console.log(save_data);
# 	 });
#
# 	 $("#revert").click(function(){
# 	   cy.load(save_data);
# 	 });
#
# 	 $('#cyeaff8120-cf16-465f-81c5-b6e50da5c767').cytoscape({
# 	   style: cytoscape.stylesheet()
# 			   .selector('node')
# 			   .css({
#              'shape': 'data(faveShape)',
#              'background-color': 'data(faveColor)',
#              'content': 'data(name)'
# 	   })
# 			   .selector('edge')
# 			   .css({
#              'target-arrow-shape': 'triangle',
#              'width': 4,
#              'line-color': '#ddd',
#              'target-arrow-color': '#ddd'
# 	   })
# 			   .selector('.highlighted')
# 			   .css({
#              'background-color': '#61bffc',
#              'line-color': '#61bffc',
#              'target-arrow-color': '#61bffc',
#              'transition-property': 'background-color, line-color, target-arrow-color',
#              'transition-duration': '0.5s'
# 	   }),
#
# 	   elements: {
# 	     nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"id": "CR1_EGFR", "parent": "EGFR", "name": "CR1"}}, {"data": {"id": "L_EGFR", "parent": "EGFR", "name": "L"}}, {"data": {"faveShape": "rectangle", "faveColor": "#FF0000", "id": "Y1068=P_EGFR", "parent": "EGFR", "name": "Y1068"}}],
# 	     edges: []
# 	   },
#
# 	   layout: {
# 	     name: 'breadthfirst',
# 	     directed: true,
# 	     roots: '#a',
# 	     padding: 10
# 	   },
#
# 	   ready: function(){
# 	     window.cy = this;
#
# 	     var bfs = cy.elements().bfs('#a', function(){}, true);
#
# 	     var i = 0;
# 	     var highlightNextEle = function(){
# 	       bfs.path[i].addClass('highlighted');
#
# 	       if( i < bfs.path.length ){
# 		 i++;
# 		 setTimeout(highlightNextEle, 1000);
# 	       }
# 	     };
#
# 	     // kick off first highlight
# 	     highlightNextEle();
# 	   }
# 	 });
#        };
#
#        var before_render = function(){
# 	 if(window['cytoscape'] === undefined){
#            console.log("wait!");
# 	   window.addEventListener("load_cytoscape", before_render);
# 	 }else{
# 	   console.log("begin rendering!");
# 	   render();
# 	 }
#        }
#
#        before_render();
#
#      })();
#     </script>
#   </head>
#   <body>
#     <div id="cyeaff8120-cf16-465f-81c5-b6e50da5c767"></div>
#     <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#     <div id="dammy" style="width:700px;height:500px"></div>
#     <div id="controller"><button id="save">Save position</button><button id="revert">Revert position</button></div>
#   </body>
# </html>

# %%
cyjs.plot_species(comp1)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cyacbab7a1-4209-47b2-97ef-a651a4c916d6 {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cyacbab7a1-4209-47b2-97ef-a651a4c916d6').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"id": "CR1_EGFR", "parent": "EGFR", "name": "CR1"}}, {"data": {"id": "L^1_EGFR", "parent": "EGFR", "name": "L"}}, {"data": {"id": "EGF", "name": "EGF"}}, {"data": {"id": "R^1_EGF", "parent": "EGF", "name": "R"}}],
#
#       edges: [{"data": {"source": "L^1_EGFR", "id": "^1", "target": "R^1_EGF"}}]
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cyacbab7a1-4209-47b2-97ef-a651a4c916d6"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>

# %%
cyjs.plot_species(comp2)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cy1ae6e6fd-a8b4-4916-9f52-2b283b604ff3 {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cy1ae6e6fd-a8b4-4916-9f52-2b283b604ff3').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"faveShape": "rectangle", "faveColor": "#FF0000", "id": "Y1068=P^1_EGFR", "parent": "EGFR", "name": "Y1068"}}, {"data": {"id": "Grb2", "name": "Grb2"}}, {"data": {"id": "SH2^1_Grb2", "parent": "Grb2", "name": "SH2"}}],
#
#       edges: [{"data": {"source": "Y1068=P^1_EGFR", "id": "^1", "target": "SH2^1_Grb2"}}]
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cy1ae6e6fd-a8b4-4916-9f52-2b283b604ff3"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>
